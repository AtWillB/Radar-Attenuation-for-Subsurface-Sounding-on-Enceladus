# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import radar_attenuation.heatmap_util as hu

# %%
heat_df_5_low = hu.mk_heatmap(5, "low_loss", "../../figures/figure2/data/temperature_profiles/")
annot = True

cmap = hu.custom_cmap()

fig, ax = plt.subplots(1, 1, figsize = (5, 4))
sns.heatmap(heat_df_5_low, cmap = cmap, ax = ax,vmin = 0, vmax = 105, annot = annot, lw = 0.5, linecolor= "black", fmt = ".3g")
# Out:
# Ice Shell Depth: 5 km, Loss Type: low_loss
# <Axes: ylabel='Regolith Depth [m]'>
